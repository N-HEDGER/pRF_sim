# %% [markdown]
# ## Prepare retinotopy prior
#
# It may be a useful resource to have some group averaged pRF estimates - so that we have some sense of what pRFs are generally like in each region of the brain.
#
# To this end, I prepare the retinotopy prior from the Benson et al 2018. Which is packaged with the neuropythy dataset.

# %%
# %load_ext autoreload
# %autoreload 2
import neuropythy as ny
import pandas as pd
import pkg_resources
import os
from pRF_sim.vis import basic_plot

subs = ny.data['benson_winawer_2018'].subjects
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-334ab3007eff> in <module>
#       7 from pRF_sim.vis import basic_plot
#       8
# ----> 9 subs = ny.data['benson_winawer_2018'].subjects
#
# ~/anaconda2/envs/py3env/lib/python3.6/site-packages/pimms/immutable.py in _imm_getattribute(self, name)
#     133             return object.__getattribute__(self, name)
#     134         (args, memfn, _) = values[name]
# --> 135         value = memfn(*[getattr(self, arg) for arg in args])
#     136         dd[name] = value
#     137         # if this is a const, it may have checks to run
#
# ~/anaconda2/envs/py3env/lib/python3.6/site-packages/neuropythy/datasets/benson_winawer_2018.py in subjects(cache_directory, create_directories, create_mode)
#     304         # make sure the data are downloaded
#     305         BensonWinawer2018Dataset.download(cache_directory, create_directories=create_directories,
# --> 306                                           mode=create_mode, overwrite=False)
#     307         # okay, next we want to setup the subjects
#     308         dat = {s:curry(BensonWinawer2018Dataset.load_subject, cache_directory, s)
#
# ~/anaconda2/envs/py3env/lib/python3.6/site-packages/neuropythy/datasets/benson_winawer_2018.py in download(path, create_directories, mode, overwrite)
#     180                 with urllib.request.urlopen(durl) as response:
#     181                     with open(tgz_file, 'wb') as fl:
# --> 182                         shutil.copyfileobj(response, fl)
#     183             if not tarfile.is_tarfile(tgz_file):
#     184                 raise ValueError('Error when downloading %s: not a tar file' % tgz_file)
#
# ~/anaconda2/envs/py3env/lib/python3.6/shutil.py in copyfileobj(fsrc, fdst, length)
#      77     """copy data from file-like object fsrc to file-like object fdst"""
#      78     while 1:
# ---> 79         buf = fsrc.read(length)
#      80         if not buf:
#      81             break
#
# ~/anaconda2/envs/py3env/lib/python3.6/http/client.py in read(self, amt)
#     457             # Amount is given, implement using readinto
#     458             b = bytearray(amt)
# --> 459             n = self.readinto(b)
#     460             return memoryview(b)[:n].tobytes()
#     461         else:
#
# ~/anaconda2/envs/py3env/lib/python3.6/http/client.py in readinto(self, b)
#     501         # connection, and the user is reading more bytes than will be provided
#     502         # (for example, reading in 1k chunks)
# --> 503         n = self.fp.readinto(b)
#     504         if not n and b:
#     505             # Ideally, we would raise IncompleteRead if the content-length
#
# ~/anaconda2/envs/py3env/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/anaconda2/envs/py3env/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# ~/anaconda2/envs/py3env/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~/anaconda2/envs/py3env/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
wcard='/var/folders/wj/n43w35jn4b77cmr_tl630q480000gn/T/npythy_data_cache_tumyzfc7/benson_winawer_2018/retinotopy/fsaverage/{hem}_{param}.mgz'

# %%
import nibabel as nib
import numpy as np
def load_param(param):
    ldat,rdat=nib.load(wcard.format(hem='lh',param=param)),nib.load(wcard.format(hem='rh',param=param))
    return np.squeeze(np.concatenate([ldat.get_data()[0],rdat.get_data()[0]],axis=0))

# %%
param_names=['vexpl','eccen','angle','prfsz']
params=np.array([load_param(param) for param in param_names])
# Out:
# /Users/nicholashedger/anaconda2/envs/py3env/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   """

# %%
ret_frame=pd.DataFrame(params.T)
ret_frame.columns=param_names

# %%
DATA_PATH = pkg_resources.resource_filename('pRF_sim', 'test/data')
ret_frame.to_csv(os.path.join(DATA_PATH,'retprior.csv'))

# %%
from pRF_sim.utils import load_retprior
from pRF_sim.utils import MMP_masker
retprior=load_retprior()

# %%
def transang(oldang):
    # We need to transform the -180 to 180 range to 0, 360
    newang=np.copy(oldang)
    
    newang[newang>0]=180-np.absolute(newang[newang>0])
    
    return newang

# %%
mp=basic_plot(np.radians(retprior['angle']),vmin=-3.14,vmax=3.14,subject='fsaverage',cmap='Retinotopy_RYBCR',colorbar=True)

# %%
def mypol2cart(r,theta):

    y = r*np.cos(theta)
    # compute y
    x =np.negative(r*np.sin(theta))
    
    return x,y

# %%
retprior['x']=y
retprior['y']=np.negative(x)

# %%
x,y=mypol2cart(retprior['eccen'],np.radians((retprior['angle'])))

# %% [markdown]
# using the MMP parcellation, I can now make a mask of say V4.

# %%
V4mask=mm.make_roi_mask('LO1')

# %%
mp=basic_plot(V4mask[-1],vmax=1,subject='fsaverage')

# %% [markdown]
# And index the retinotopy prior with this to see what kinds of pRF properties there are in this region.

# %%
retprior.loc[V4mask[-1]]
# Out:
#         Unnamed: 0     vexpl     eccen       angle     prfsz         x  \
# 1258          1258  0.588048  3.264000  101.250000  3.620387  3.201283
# 2290          2290  0.675492  2.661263  105.724580  2.513417  2.561667
# 2291          2291  0.673065  2.026848  110.128600  1.832395  1.903054
# 2292          2292  0.658989  4.937992  103.092530  3.525837  4.809631
# 2343          2343  0.692319  1.366938   97.715576  1.303132  1.354563
# ...            ...       ...       ...         ...       ...       ...
# 322497      322497  0.751873  1.155189  -96.481250  1.231564 -1.147806
# 322498      322498  0.751873  1.155189  -96.481250  1.231564 -1.147806
# 322499      322499  0.771763  0.999262  -94.135820  0.870615 -0.996660
# 322500      322500  0.771763  0.999262  -94.135820  0.870615 -0.996660
# 322501      322501  0.826070  0.803856 -106.166980  0.678535 -0.772067
#
#                y
# 1258    0.636775
# 2290    0.721238
# 2291    0.697496
# 2292    1.118575
# 2343    0.183519
# ...          ...
# 322497  0.130396
# 322498  0.130396
# 322499  0.072068
# 322500  0.072068
# 322501  0.223824
#
# [586 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
plt.hist(retprior.loc[V4mask[-1]]['prfsz'])
# Out:
# (array([1.087e+03, 4.920e+02, 3.710e+02, 3.850e+02, 3.570e+02, 1.000e+01,
#         1.510e+02, 4.000e+00, 0.000e+00, 1.000e+00]),
#  array([0.22579308, 0.71701337, 1.20823366, 1.69945396, 2.19067425,
#         2.68189454, 3.17311483, 3.66433512, 4.15555542, 4.64677571,
#         5.137996  ]),
#  <a list of 10 Patch objects>)
